# %% [markdown]
# ***
#
# # `GPT-2 Questioner Training`
# Fine-tune a GPT-2 model to be inquisitive.
#
# ***

# %%
import gpt_2_simple as gpt2

# %%
# Download model
model_name = '124M'
gpt2.download_gpt2(model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 328Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 27.6Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 385Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:04, 106Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 359Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 36.7Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 37.5Mit/s]

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess, 'nq_data_50k.txt', model_name=model_name, steps=500)
# Out:
# WARNING:tensorflow:From /home/owen/.local/lib/python3.6/site-packages/gpt_2_simple/src/sample.py:17: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# WARNING:tensorflow:From /home/owen/.local/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:13<00:00, 13.82s/it]
# dataset has 2282471 tokens
# Training...
# [1 | 7.40] loss=3.63 avg=3.63
# [2 | 8.65] loss=3.50 avg=3.56
# ...

# %%
from postprocess_utils import gpt2_gen_question
gpt2_gen_question(sess, 'A man riding a wave on top of a surfboard.')
# Out:
# A man riding a wave on top of a surfboard.
# Is there a difference between a wave and wave propelled?
# Gigantic (sometimes spelled Gigantic) is a British rock band that was formed
